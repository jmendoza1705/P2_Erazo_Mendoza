# %%
import pandas as pd
data0 =  pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data', header=None)
names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca",
         "thal", "num"]
data0.columns = names
data0['ca'] = pd.to_numeric(data0['ca'], errors='coerce')
data0['thal'] = pd.to_numeric(data0['thal'], errors='coerce')
data0 = data0.astype(float)
data0 = data0.dropna()

data0
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0  0.0
# 1      2.0  3.0   3.0  2.0
# 2      2.0  2.0   7.0  1.0
# 3      3.0  0.0   3.0  0.0
# 4      1.0  0.0   3.0  0.0
# ..     ...  ...   ...  ...
# 297    2.0  0.0   7.0  1.0
# 298    2.0  0.0   7.0  1.0
# 299    2.0  2.0   7.0  2.0
# 300    2.0  1.0   7.0  3.0
# 301    2.0  1.0   3.0  1.0
#
# [297 rows x 14 columns]

# %%
import psycopg2
engine = psycopg2.connect(
dbname="datap2",
user="postgres",
password="proyecto2",
host="datap2.colrzll4geas.us-east-1.rds.amazonaws.com",
port='5432'
)

cursor = engine.cursor()

query = """
SELECT * 
FROM pg_catalog.pg_tables 
WHERE schemaname='public';"""
cursor.execute(query)
result = cursor.fetchall()
result
# Out:
# [('public', 'datap2', 'postgres', None, False, False, False, False)]

# %%
from sqlalchemy import create_engine, text
engine=create_engine('postgresql://postgres:proyecto2@datap2.colrzll4geas.us-east-1.rds.amazonaws.com:5432/datap2')
data0.to_sql('datap2', con=engine, if_exists="replace", index=False)

datos_p2 = pd.read_sql(text("SELECT * FROM datap2"), con=engine.connect())
datos_p2
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 292  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 293  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 294  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 295  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 296  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0  0.0
# 1      2.0  3.0   3.0  2.0
# 2      2.0  2.0   7.0  1.0
# 3      3.0  0.0   3.0  0.0
# 4      1.0  0.0   3.0  0.0
# ..     ...  ...   ...  ...
# 292    2.0  0.0   7.0  1.0
# 293    2.0  0.0   7.0  1.0
# 294    2.0  2.0   7.0  2.0
# 295    2.0  1.0   7.0  3.0
# 296    2.0  1.0   3.0  1.0
#
# [297 rows x 14 columns]
